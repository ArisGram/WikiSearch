# %% [markdown]
# # Εργασία Ανάκτησης Πληροφορίας
# ## Δημιουργία μηχανής αναζήτησης
# ### Βήμα 1. Συλλογή δεδομένων:

# %%
import json

# Διαβάζουμε το αρχείο JSON
with open('articles.json', 'r', encoding='utf-8') as file:
    articles = json.load(file)

# Εξάγουμε τα δεδομένα των άρθρων
documents = []
for article in articles:
    doc = {
        'ID': article.get('ID'),
        'Title': article.get('Title'),
        'Body': article.get('Body', ''),
        'URL': article.get('URL'),
    }
    documents.append(doc)

# Εμφανίζουμε τον αριθμό των εγγράφων που συλλέχθηκαν
print(f"Συλλέχθηκαν {len(documents)} άρθρα.")

# Παράδειγμα εμφάνισης ενός εγγράφου
print(json.dumps(documents[0], indent=4, ensure_ascii=False))
# Out:
# Συλλέχθηκαν 1000 άρθρα.
# {
#     "ID": 3,
#     "Title": "Meir Shalev",
#     "Body": "Israeli writer (1948–2023)\n\n\nMeir ShalevShalev in 2015Bornמאיר שלו(1948-07-29)29 July 1948Nahalal, IsraelDied11 April 2023(2023-04-11) (aged 74)Alonei Abba, IsraelLanguageHebrewNationalityIsraeliNotable awardsBernstein Prize,Brenner Prize\nMeir Shalev and the theater performance team at the end of the play \"Uncle Aaron and his Rain\" which won the first prize at the Haifa International Children's Theater Festival in 2017\nThe grave of Meir Shalev is covered with flowers after the funeral, April 13, 2023\nMeir Shalev (Hebrew: מאיר שלו; 29 July 1948 – 11 April 2023) was an Israeli writer and newspaper columnist[1] for the daily Yedioth Ahronoth. Shalev's books have been translated into 26 languages.[2]\n\n\nBiography[edit]\nShalev was born in Nahalal, Israel. Later he lived in Jerusalem and at Ginosar with his family. He is the son of the Jerusalem poet Yitzhak Shalev. His cousin Zeruya Shalev is also a writer.\nShalev was drafted into the IDF in 1966, and did his military service in the Golani Brigade. He served as a soldier, a squad leader  in the brigade's reconnaissance company. Shalev fought in The Six Day War,[3] and a few months after the war was injured in a friendly fire incident.\nShalev began his career by presenting ironic features on television and radio. He also moderated the program Erev Shabbat (\"Friday night\") on Israel channel one. His first novel, The Blue Mountain, was published in 1988.\nShalev also wrote non-fiction, children's books, and a weekly column in the weekend edition of Yediot Ahronot.\nShalev lived in the Jezreel Valley until his death on 11 April 2023, following a prolonged battle with cancer. He was 74.[2] Upon news of Shalev's death, Israeli President Isaac Herzog expressed condolences: \"Israel has lost one of its greatest storytellers, he made us love the Hebrew language, the Hebrew Bible, and ourselves, the Jewish People\".[4]\n\nViews and opinions[edit]\nAccording to a January 2009 interview, Shalev identified with the Israeli left and believed that the conflict with the Palestinians could be resolved by establishing two states for two peoples. However, he expressed disappointment towards the extremism in the Palestinian camp, saying: \"Radical Palestinians still say that the only solution would be for all Jews to pack their bags and return to where their grandparents came from. When there are no more Jews left in the Middle East, then the problem is solved, according to their logic. As long as they continue to think that way, there will be no peace. We are here and we are going to stay. Only after that fact is generally accepted can progress be made.\"[5]\n\nAwards and recognition[edit]\nBernstein Prize (original Hebrew novel category) (1989)[6]\nJuliet Club Prize (1999)[6]\nChiavari Prize (1999)[6]\nBrenner Prize (Israel) for A Pigeon and a Boy (2006)\nNational Jewish Book Award for A Pigeon and a Boy (2007)[6][7]\nPorta Siberia Prize (2009)[6]\nPratt Award for Environmental Journalism (2009)[6]\nNeuman Prize (2011)[6]\nChevalier of the Ordre des Arts et des Lettres, along with Michal Govrin, in 2018[8]\nPublished works[edit]\nFiction[edit]\n1988 The Blue Mountain ISBN 0-06-016691-6 (1988, originally published in Hebrew as Roman Rusi) English translation in 1991 by Hillel Halkin. Reprinted, 2010\n1991 Esau ISBN 0-06-019040-X\n1994 As a Few Days, also called The Four Meals or The Loves of Judith ISBN 1-84195-114-5[9]\n1998 His House in the Desert (or \"Alone in the Desert\")\n2002 Fontanelle ISBN 3-257-23554-2\n2006 A Pigeon and A Boy (originally published in Hebrew as Yona v'naar by Am Oved Publishers, Tel Aviv), translated by Evan Fallenberg, Random House, New York, ISBN 978-0-8052-4251-5\n2013 Two She-Bears[2]\n2022 'Al Tesaper le-Akhicha (Hebrew: \"Don't Tell Your Brother\")\nNon-fiction[edit]\n1985 Bible Now, a book containing interpretations of Hebrew Bible stories from his personal point of view, which first appeared in the newspaper Haaretz.\nElements of Conjura ...
#     "URL": "https://en.wikipedia.org/wiki/Meir_Shalev"
# }

# %% [markdown]
# ### Βήμα 2. Προεπεξεργασία κειμένου (Text Processing):

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# Κατεβάζουμε τα απαραίτητα δεδομένα για το nltk
nltk.download('punkt')
nltk.download('stopwords')

# Stop words και stemming
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

# Συνάρτηση για καθαρισμό κειμένου
def preprocess_text(text):
    # Αφαίρεση ειδικών χαρακτήρων
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Μετατροπή σε πεζά γράμματα
    text = text.lower()
    # Tokenization
    tokens = word_tokenize(text)
    # Αφαίρεση stop-words και stemming
    filtered_tokens = [stemmer.stem(word) for word in tokens if word not in stop_words]
    return ' '.join(filtered_tokens)

# Προεπεξεργασία όλων των άρθρων
for doc in documents:
    doc['Processed_Body'] = preprocess_text(doc['Body'])

# Αποθήκευση προεπεξεργασμένων δεδομένων
with open('processed_articles.json', 'w', encoding='utf-8') as file:
    json.dump(documents, file, indent=4, ensure_ascii=False)

print("Η προεπεξεργασία ολοκληρώθηκε και τα δεδομένα αποθηκεύτηκαν στο 'processed_articles.json'.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\agram\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\agram\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Η προεπεξεργασία ολοκληρώθηκε και τα δεδομένα αποθηκεύτηκαν στο 'processed_articles.json'.

# %% [markdown]
# ### Βήμα 3. Ευρετήριο (Indexing):

# %%
from collections import defaultdict

# Δημιουργία ανεστραμμένου ευρετηρίου
def create_inverted_index(documents):
    inverted_index = defaultdict(list)  # Λεξικό για το ευρετήριο
    for doc in documents:
        doc_id = doc['ID']
        words = doc['Processed_Body'].split()
        word_counts = defaultdict(int)  # Μετρητής λέξεων στο έγγραφο
        for word in words:
            word_counts[word] += 1
        
        # Ενημέρωση του ανεστραμμένου ευρετηρίου
        for word, count in word_counts.items():
            inverted_index[word].append({'doc_id': doc_id, 'frequency': count})
    
    return inverted_index

# Δημιουργούμε το ευρετήριο
inverted_index = create_inverted_index(documents)

# Αποθήκευση του ευρετηρίου σε αρχείο
with open('inverted_index.json', 'w', encoding='utf-8') as file:
    json.dump(inverted_index, file, indent=4, ensure_ascii=False)

print("Το ανεστραμμένο ευρετήριο δημιουργήθηκε και αποθηκεύτηκε στο 'inverted_index.json'.")
# Out:
# Το ανεστραμμένο ευρετήριο δημιουργήθηκε και αποθηκεύτηκε στο 'inverted_index.json'.

# %% [markdown]
# ### Βήμα 4. Μηχανή αναζήτησης (Search Engine):
# #### α) Επεξεργασία ερωτήματος (Query Processing):

# %%
# Συνάρτηση για την επεξεργασία του ερωτήματος
def process_query(query):
    query = re.sub(r'[^a-zA-Z\s]', '', query).lower()
    tokens = word_tokenize(query)
    filtered_tokens = [stemmer.stem(word) for word in tokens if word not in stop_words]
    return filtered_tokens

# Συνάρτηση για την εκτέλεση αναζήτησης
def search(query, inverted_index):
    if "AND" in query:
        # Boolean: AND
        terms = query.split("AND")
        if len(terms) == 2:
            term1 = process_query(terms[0].strip())[0]
            term2 = process_query(terms[1].strip())[0]

            docs1 = {doc['doc_id'] for doc in inverted_index.get(term1, [])}
            docs2 = {doc['doc_id'] for doc in inverted_index.get(term2, [])}
            
            results = list(docs1 & docs2)
            return results
        else:
            print("Σφάλμα στο ερώτημα. Χρησιμοποιήστε σωστή σύνταξη: text1 AND text2.")
            return []

    elif "OR" in query:
        # Boolean: OR
        terms = query.split("OR")
        results = set()
        for term in terms:
            term = process_query(term.strip())[0]
            results.update({doc['doc_id'] for doc in inverted_index.get(term, [])})
        return list(results)

    elif "NOT" in query:
        # Boolean: NOT
        term = process_query(query.split("NOT")[1].strip())[0]
        all_docs = {doc['ID'] for doc in documents}
        exclude_docs = {doc['doc_id'] for doc in inverted_index.get(term, [])}
        results = list(all_docs - exclude_docs)
        return results

    else:
        # Μοναδικός όρος αναζήτησης
        term = process_query(query.strip())[0]
        results = [doc['doc_id'] for doc in inverted_index.get(term, [])]
        return results

# Διαρκής αναζήτηση μέχρι ο χρήστης να σταματήσει
while True:
    query = input("Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): ").strip()
    if query.lower() == 'exit':
        print("Τερματισμός αναζήτησης.")
        break

    results = search(query, inverted_index)

    # Προβολή αποτελεσμάτων
    if results:
        print(f"Βρέθηκαν {len(results)} σχετικά έγγραφα:\n")
        for doc_id in results:
            doc = next((d for d in documents if d['ID'] == doc_id), None)
            print(f"ID: {doc['ID']}, Τίτλος: {doc['Title']}, URL: {doc['URL']}")
    else:
        print("Δε βρέθηκαν σχετικά έγγραφα.")
# Out:
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): machine and gift
# Βρέθηκαν 80 σχετικά έγγραφα:
#
# ID: 4, Τίτλος: Sikh culture, URL: https://en.wikipedia.org/wiki/Sikh_culture
# ID: 26, Τίτλος: Henry J. Abraham, URL: https://en.wikipedia.org/wiki/Henry_J._Abraham
# ID: 37, Τίτλος: Universal Channel (Polish TV channel), URL: https://en.wikipedia.org/wiki/Universal_Channel_(Polish_TV_channel)
# ID: 47, Τίτλος: Killzone 3, URL: https://en.wikipedia.org/wiki/Killzone_3
# ID: 44, Τίτλος: Cologne Stadtbahn, URL: https://en.wikipedia.org/wiki/Cologne_Stadtbahn
# ID: 58, Τίτλος: Transport in Gabon, URL: https://en.wikipedia.org/wiki/Transport_in_Gabon
# ID: 68, Τίτλος: University North, URL: https://en.wikipedia.org/wiki/University_North
# ID: 80, Τίτλος: Baltimore Saturday Visiter, URL: https://en.wikipedia.org/wiki/Baltimore_Saturday_Visiter
# ID: 88, Τίτλος: Frederick John Widgery, URL: https://en.wikipedia.org/wiki/Frederick_John_Widgery
# ID: 93, Τίτλος: Pulan Visaranai 2, URL: https://en.wikipedia.org/wiki/Pulan_Visaranai_2
# ID: 99, Τίτλος: The Human Abstract (band), URL: https://en.wikipedia.org/wiki/The_Human_Abstract_(band)
# ID: 113, Τίτλος: Dax (rapper), URL: https://en.wikipedia.org/wiki/Dax_(rapper)
# ID: 116, Τίτλος: Cindy Williams, URL: https://en.wikipedia.org/wiki/Cindy_Williams
# ID: 121, Τίτλος: Tom Seymour (politician), URL: https://en.wikipedia.org/wiki/Tom_Seymour_(politician)
# ID: 159, Τίτλος: Pedro Toledo, URL: https://en.wikipedia.org/wiki/Pedro_Toledo
# ID: 169, Τίτλος: Summer (Harisu album), URL: https://en.wikipedia.org/wiki/Summer_(Harisu_album)
# ID: 179, Τίτλος: 2006 World Weightlifting Championships – Women's 58 kg, URL: https://en.wikipedia.org/wiki/2006_World_Weightlifting_Championships_%E2%80%93_Women's_58_kg
# ID: 195, Τίτλος: Jean-Baptiste de La Rose, URL: https://en.wikipedia.org/wiki/Jean-Baptiste_de_La_Rose
# ID: 197, Τίτλος: Normal schools in the United States, URL: https://en.wikipedia.org/wiki/Normal_schools_in_the_United_States
# ID: 211, Τίτλος: Francis of Denmark, URL: https://en.wikipedia.org/wiki/Francis_of_Denmark
# ID: 227, Τίτλος: Alamo City Rollergirls, URL: https://en.wikipedia.org/wiki/Alamo_City_Rollergirls
# ID: 229, Τίτλος: Otto Mueller (politician), URL: https://en.wikipedia.org/wiki/Otto_Mueller_(politician)
# ID: 228, Τίτλος: 1997 Japanese Regional Leagues, URL: https://en.wikipedia.org/wiki/1997_Japanese_Regional_Leagues
# ID: 286, Τίτλος: Gonchary, URL: https://en.wikipedia.org/wiki/Gonchary
# ID: 285, Τίτλος: Carl Jan Granqvist, URL: https://en.wikipedia.org/wiki/Carl_Jan_Granqvist
# ID: 293, Τίτλος: Anne Evans Estabrook, URL: https://en.wikipedia.org/wiki/Anne_Evans_Estabrook
# ID: 317, Τίτλος: Hurricane Cindy tornado outbreak, URL: https://en.wikipedia.org/wiki/Hurricane_Cindy_tornado_outbreak
# ID: 311, Τίτλος: Mellisa Hollingsworth, URL: https://en.wikipedia.org/wiki/Mellisa_Hollingsworth
# ID: 359, Τίτλος: José Ricardo Rambo, URL: https://en.wikipedia.org/wiki/Jos%C3%A9_Ricardo_Rambo
# ID: 368, Τίτλος: Do Ngak Kunphen Ling Tibetan Buddhist Center for Universal Peace, URL: https://en.wikipedia.org/wiki/Do_Ngak_Kunphen_Ling_Tibetan_Buddhist_Center_for_Universal_Peace
# ID: 366, Τίτλος: brickOS, URL: https://en.wikipedia.org/wiki/BrickOS
# ID: 370, Τίτλος: Sarojini Sahoo, URL: https://en.wikipedia.org/wiki/Sarojini_Sahoo
# ID: 393, Τίτλος: Russian Party of Freedom and Justice, URL: https://en.wikipedia.org/wiki/Russian_Party_of_Freedom_and_Justice
# ID: 397, Τίτλος: AIDS-related lymphoma, URL: https://en.wikipedia.org/wiki/AIDS-related_lymphoma
# ID: 400, Τίτλος: Mike Ireland, URL: https://en.wikipedia.org/wiki/Mike_Ireland
# ID: 405, Τίτλος: Tomohiro Hatta, URL: https://en.wikipedia.org/wiki/Tomohiro_Hatta
# ID: 450, Τίτλος: ROKS Andong, URL: https://en.wikipedia.org/wiki/ROKS_Andong
# ID: 441, Τίτλος: 2010 in British music charts, URL: https://en.wikipedia.org/wiki/2010_in_British_music_charts
# ID: 451, Τίτλος: Michel Majerus, URL: https://en.wikipedia.org/wiki/Michel_Majerus
# ID: 490, Τίτλος: Bobby Etheridge, URL: https://en.wikipedia.org/wiki/Bobby_Etheridge
# ID: 493, Τίτλος: Z-class Melbourne tram, URL: https://en.wikipedia.org/wiki/Z-class_Melbourne_tram
# ID: 510, Τίτλος: Nikolai Tikhomirov, URL: https://en.wikipedia.org/wiki/Nikolai_Tikhomirov
# ID: 516, Τίτλος: Paperback, URL: https://en.wikipedia.org/wiki/Paperback
# ID: 513, Τίτλος: Löwinger-Bühne, URL: https://en.wikipedia.org/wiki/L%C3%B6winger-B%C3%BChne
# ID: 523, Τίτλος: Henry (Obotrite prince), URL: https://en.wikipedia.org/wiki/Henry_(Obotrite_prince)
# ID: 558, Τίτλος: Chakobo language, URL: https://en.wikipedia.org/wiki/Chakobo_language
# ID: 562, Τίτλος: Basketball Löwen Braunschweig, URL: https://en.wikipedia.org/wiki/Basketball_L%C3%B6wen_Braunschweig
# ID: 568, Τίτλος: 1000 Genomes Project, URL: https://en.wikipedia.org/wiki/1000_Genomes_Project
# ID: 564, Τίτλος: Dr. Plonk, URL: https://en.wikipedia.org/wiki/Dr._Plonk
# ID: 576, Τίτλος: Ho-Sung Pak, URL: https://en.wikipedia.org/wiki/Ho-Sung_Pak
# ID: 586, Τίτλος: Führersonderzug, URL: https://en.wikipedia.org/wiki/F%C3%BChrersonderzug
# ID: 597, Τίτλος: Danny Kopec, URL: https://en.wikipedia.org/wiki/Danny_Kopec
# ID: 605, Τίτλος: Senecio madagascariensis, URL: https://en.wikipedia.org/wiki/Senecio_madagascariensis
# ID: 619, Τίτλος: Kevin Michael (album), URL: https://en.wikipedia.org/wiki/Kevin_Michael_(album)
# ID: 632, Τίτλος: Coprocanthon, URL: https://en.wikipedia.org/wiki/Coprocanthon
# ID: 647, Τίτλος: Johnsonville railway station, URL: https://en.wikipedia.org/wiki/Johnsonville_railway_station
# ID: 649, Τίτλος: Bhutan–China relations, URL: https://en.wikipedia.org/wiki/Bhutan%E2%80%93China_relations
# ID: 678, Τίτλος: History of Rutgers University, URL: https://en.wikipedia.org/wiki/History_of_Rutgers_University
# ID: 682, Τίτλος: Marguerite de Saint-Marceaux, URL: https://en.wikipedia.org/wiki/Marguerite_de_Saint-Marceaux
# ID: 692, Τίτλος: The Last Day (Doctor Who), URL: https://en.wikipedia.org/wiki/The_Last_Day_(Doctor_Who)
# ID: 691, Τίτλος: USS George Philip, URL: https://en.wikipedia.org/wiki/USS_George_Philip
# ID: 732, Τίτλος: Birotron, URL: https://en.wikipedia.org/wiki/Birotron
# ID: 748, Τίτλος: Krista Phillips, URL: https://en.wikipedia.org/wiki/Krista_Phillips
# ID: 745, Τίτλος: Tomasz Kucharzewski, URL: https://en.wikipedia.org/wiki/Tomasz_Kucharzewski
# ID: 762, Τίτλος: Hordubalové, URL: https://en.wikipedia.org/wiki/Hordubalov%C3%A9
# ID: 777, Τίτλος: Kiyoshiro Imawano, URL: https://en.wikipedia.org/wiki/Kiyoshiro_Imawano
# ID: 798, Τίτλος: Ana María Simo, URL: https://en.wikipedia.org/wiki/Ana_Mar%C3%ADa_Simo
# ID: 816, Τίτλος: Swedes, URL: https://en.wikipedia.org/wiki/Swedes
# ID: 823, Τίτλος: Toofan (MRAP), URL: https://en.wikipedia.org/wiki/Toofan_(MRAP)
# ID: 834, Τίτλος: June Allyson, URL: https://en.wikipedia.org/wiki/June_Allyson
# ID: 837, Τίτλος: Soldiers of the Night, URL: https://en.wikipedia.org/wiki/Soldiers_of_the_Night
# ID: 870, Τίτλος: Reification (computer science), URL: https://en.wikipedia.org/wiki/Reification_(computer_science)
# ID: 866, Τίτλος: Bomb (tank), URL: https://en.wikipedia.org/wiki/Bomb_(tank)
# ID: 903, Τίτλος: Gel bracelet, URL: https://en.wikipedia.org/wiki/Gel_bracelet
# ID: 905, Τίτλος: Luton Town MIGs, URL: https://en.wikipedia.org/wiki/Luton_Town_MIGs
# ID: 915, Τίτλος: RCS-4, URL: https://en.wikipedia.org/wiki/RCS-4
# ID: 917, Τίτλος: Dave Rubinstein, URL: https://en.wikipedia.org/wiki/Dave_Rubinstein
# ID: 925, Τίτλος: Justin Jackson (basketball, born 1990), URL: https://en.wikipedia.org/wiki/Justin_Jackson_(basketball,_born_1990)
# ID: 942, Τίτλος: R. Perry Beaver, URL: https://en.wikipedia.org/wiki/R._Perry_Beaver
# ID: 962, Τίτλος: John D. Lafferty, URL: https://en.wikipedia.org/wiki/John_D._Lafferty
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): open or christmas
# Βρέθηκαν 175 σχετικά έγγραφα:
#
# ID: 2, Τίτλος: New York State Canal Corporation, URL: https://en.wikipedia.org/wiki/New_York_State_Canal_Corporation
# ID: 17, Τίτλος: Michel Casseux, URL: https://en.wikipedia.org/wiki/Michel_Casseux
# ID: 15, Τίτλος: Smidtia, URL: https://en.wikipedia.org/wiki/Smidtia
# ID: 25, Τίτλος: Bekim Erkoceviç, URL: https://en.wikipedia.org/wiki/Bekim_Erkocevi%C3%A7
# ID: 40, Τίτλος: Bian stones, URL: https://en.wikipedia.org/wiki/Bian_stones
# ID: 32, Τίτλος: Cacozelia elegans, URL: https://en.wikipedia.org/wiki/Cacozelia_elegans
# ID: 39, Τίτλος: Devario manipurensis, URL: https://en.wikipedia.org/wiki/Devario_manipurensis
# ID: 47, Τίτλος: Killzone 3, URL: https://en.wikipedia.org/wiki/Killzone_3
# ID: 44, Τίτλος: Cologne Stadtbahn, URL: https://en.wikipedia.org/wiki/Cologne_Stadtbahn
# ID: 49, Τίτλος: Mysouffa, URL: https://en.wikipedia.org/wiki/Mysouffa
# ID: 54, Τίτλος: Conical combination, URL: https://en.wikipedia.org/wiki/Conical_combination
# ID: 57, Τίτλος: Dendrobium dickasonii, URL: https://en.wikipedia.org/wiki/Dendrobium_dickasonii
# ID: 79, Τίτλος: Urgleptes amplicollis, URL: https://en.wikipedia.org/wiki/Urgleptes_amplicollis
# ID: 92, Τίτλος: Aglossosia semisericea, URL: https://en.wikipedia.org/wiki/Aglossosia_semisericea
# ID: 95, Τίτλος: Elora Rocks, URL: https://en.wikipedia.org/wiki/Elora_Rocks
# ID: 98, Τίτλος: Pseudanthias pleurotaenia, URL: https://en.wikipedia.org/wiki/Pseudanthias_pleurotaenia
# ID: 111, Τίτλος: Rubis Energy Kenya, URL: https://en.wikipedia.org/wiki/Rubis_Energy_Kenya
# ID: 114, Τίτλος: 2019–20 Levante UD season, URL: https://en.wikipedia.org/wiki/2019%E2%80%9320_Levante_UD_season
# ID: 129, Τίτλος: Disability fraud, URL: https://en.wikipedia.org/wiki/Disability_fraud
# ID: 126, Τίτλος: Metsatöll, URL: https://en.wikipedia.org/wiki/Metsat%C3%B6ll
# ID: 125, Τίτλος: 1938 VPI Gobblers football team, URL: https://en.wikipedia.org/wiki/1938_VPI_Gobblers_football_team
# ID: 134, Τίτλος: Jacopo Tiepolo, URL: https://en.wikipedia.org/wiki/Jacopo_Tiepolo
# ID: 140, Τίτλος: Didymocyrtidium, URL: https://en.wikipedia.org/wiki/Didymocyrtidium
# ID: 138, Τίτλος: Andrew Campbell (golfer), URL: https://en.wikipedia.org/wiki/Andrew_Campbell_(golfer)
# ID: 131, Τίτλος: Flavobacterium cucumis, URL: https://en.wikipedia.org/wiki/Flavobacterium_cucumis
# ID: 155, Τίτλος: List of U.S. Highways in Montana, URL: https://en.wikipedia.org/wiki/List_of_U.S._Highways_in_Montana
# ID: 168, Τίτλος: Before the Law, URL: https://en.wikipedia.org/wiki/Before_the_Law
# ID: 166, Τίτλος: Uresiphita ornithopteralis, URL: https://en.wikipedia.org/wiki/Uresiphita_ornithopteralis
# ID: 167, Τίτλος: Dardanelle pontoon bridge, URL: https://en.wikipedia.org/wiki/Dardanelle_pontoon_bridge
# ID: 172, Τίτλος: Screenplay, URL: https://en.wikipedia.org/wiki/Screenplay
# ID: 177, Τίτλος: Zobellella denitrificans, URL: https://en.wikipedia.org/wiki/Zobellella_denitrificans
# ID: 181, Τίτλος: 1750, URL: https://en.wikipedia.org/wiki/1750
# ID: 186, Τίτλος: Water by the Spoonful, URL: https://en.wikipedia.org/wiki/Water_by_the_Spoonful
# ID: 183, Τίτλος: Acacia decurrens, URL: https://en.wikipedia.org/wiki/Acacia_decurrens
# ID: 197, Τίτλος: Normal schools in the United States, URL: https://en.wikipedia.org/wiki/Normal_schools_in_the_United_States
# ID: 194, Τίτλος: 1910 Vermont Green and Gold football team, URL: https://en.wikipedia.org/wiki/1910_Vermont_Green_and_Gold_football_team
# ID: 200, Τίτλος: Platform Prize, URL: https://en.wikipedia.org/wiki/Platform_Prize
# ID: 196, Τίτλος: Paraguayan punaré, URL: https://en.wikipedia.org/wiki/Paraguayan_punar%C3%A9
# ID: 192, Τίτλος: Third Shadow Cabinet of Andrew RT Davies, URL: https://en.wikipedia.org/wiki/Third_Shadow_Cabinet_of_Andrew_RT_Davies
# ID: 206, Τίτλος: Spirituals, URL: https://en.wikipedia.org/wiki/Spirituals
# ID: 208, Τίτλος: 2014 Corpus Christi Fury season, URL: https://en.wikipedia.org/wiki/2014_Corpus_Christi_Fury_season
# ID: 204, Τίτλος: Bartonella heixiaziensis, URL: https://en.wikipedia.org/wiki/Bartonella_heixiaziensis
# ID: 219, Τίτλος: Neolophosia, URL: https://en.wikipedia.org/wiki/Neolophosia
# ID: 220, Τίτλος: Agreement on Port State Measures to Prevent, Deter and Eliminate Illegal, Unreported and Unregulated Fishing, URL: https://en.wikipedia.org/wiki/Agreement_on_Port_State_Measures_to_Prevent,_Deter_and_Eliminate_Illegal,_Unreported_and_Unregulated_Fishing
# ID: 232, Τίτλος: Sisyrinchium funereum, URL: https://en.wikipedia.org/wiki/Sisyrinchium_funereum
# ID: 236, Τίτλος: Heliogomphus ceylonicus, URL: https://en.wikipedia.org/wiki/Heliogomphus_ceylonicus
# ID: 250, Τίτλος: Ancylosis leucocephala, URL: https://en.wikipedia.org/wiki/Ancylosis_leucocephala
# ID: 245, Τίτλος: United Supermarkets, URL: https://en.wikipedia.org/wiki/United_Supermarkets
# ID: 242, Τίτλος: Garth Dawley, URL: https://en.wikipedia.org/wiki/Garth_Dawley
# ID: 251, Τίτλος: Kiss Me, Kill Me, URL: https://en.wikipedia.org/wiki/Kiss_Me,_Kill_Me
# ID: 262, Τίτλος: List of neighbourhoods of Kollam, URL: https://en.wikipedia.org/wiki/List_of_neighbourhoods_of_Kollam
# ID: 267, Τίτλος: Paan Singh Tomar, URL: https://en.wikipedia.org/wiki/Paan_Singh_Tomar
# ID: 265, Τίτλος: Scleronema (plant), URL: https://en.wikipedia.org/wiki/Scleronema_(plant)
# ID: 261, Τίτλος: Conotalis aurantifascia, URL: https://en.wikipedia.org/wiki/Conotalis_aurantifascia
# ID: 276, Τίτλος: Paramysis nouveli, URL: https://en.wikipedia.org/wiki/Paramysis_nouveli
# ID: 277, Τίτλος: Cystoporida, URL: https://en.wikipedia.org/wiki/Cystoporida
# ID: 283, Τίτλος: 1956 Palanca Awards, URL: https://en.wikipedia.org/wiki/1956_Palanca_Awards
# ID: 281, Τίτλος: 2024 Córdoba Open, URL: https://en.wikipedia.org/wiki/2024_C%C3%B3rdoba_Open
# ID: 298, Τίτλος: Iskandar Widjaja, URL: https://en.wikipedia.org/wiki/Iskandar_Widjaja
# ID: 299, Τίτλος: 2010 in association football, URL: https://en.wikipedia.org/wiki/2010_in_association_football
# ID: 309, Τίτλος: NASDAQ futures, URL: https://en.wikipedia.org/wiki/NASDAQ_futures
# ID: 308, Τίτλος: Elegantogyaritus wakaharai, URL: https://en.wikipedia.org/wiki/Elegantogyaritus_wakaharai
# ID: 307, Τίτλος: HB Ice Cream, URL: https://en.wikipedia.org/wiki/HB_Ice_Cream
# ID: 322, Τίτλος: Sergei Movsesian, URL: https://en.wikipedia.org/wiki/Sergei_Movsesian
# ID: 340, Τίτλος: Stictogryllacris quadripunctata, URL: https://en.wikipedia.org/wiki/Stictogryllacris_quadripunctata
# ID: 342, Τίτλος: Fantastic Planet (Failure album), URL: https://en.wikipedia.org/wiki/Fantastic_Planet_(Failure_album)
# ID: 348, Τίτλος: Selenogyrus brunneus, URL: https://en.wikipedia.org/wiki/Selenogyrus_brunneus
# ID: 347, Τίτλος: Renodesta ramsdalei, URL: https://en.wikipedia.org/wiki/Renodesta_ramsdalei
# ID: 364, Τίτλος: Khabur ware, URL: https://en.wikipedia.org/wiki/Khabur_ware
# ID: 369, Τίτλος: Pakistan Open, URL: https://en.wikipedia.org/wiki/Pakistan_Open
# ID: 368, Τίτλος: Do Ngak Kunphen Ling Tibetan Buddhist Center for Universal Peace, URL: https://en.wikipedia.org/wiki/Do_Ngak_Kunphen_Ling_Tibetan_Buddhist_Center_for_Universal_Peace
# ID: 370, Τίτλος: Sarojini Sahoo, URL: https://en.wikipedia.org/wiki/Sarojini_Sahoo
# ID: 371, Τίτλος: Symphlebia indistincta, URL: https://en.wikipedia.org/wiki/Symphlebia_indistincta
# ID: 379, Τίτλος: Trypanaresta delicatella, URL: https://en.wikipedia.org/wiki/Trypanaresta_delicatella
# ID: 395, Τίτλος: Athous, URL: https://en.wikipedia.org/wiki/Athous
# ID: 394, Τίτλος: Hesperentomon kuratai, URL: https://en.wikipedia.org/wiki/Hesperentomon_kuratai
# ID: 420, Τίτλος: Jim Kaat, URL: https://en.wikipedia.org/wiki/Jim_Kaat
# ID: 426, Τίτλος: Mark Scatterday, URL: https://en.wikipedia.org/wiki/Mark_Scatterday
# ID: 443, Τίτλος: Rachel Mason, URL: https://en.wikipedia.org/wiki/Rachel_Mason
# ID: 449, Τίτλος: Chaudhary Charan Singh Haryana Agricultural University Sports Complex, URL: https://en.wikipedia.org/wiki/Chaudhary_Charan_Singh_Haryana_Agricultural_University_Sports_Complex
# ID: 454, Τίτλος: Niña, URL: https://en.wikipedia.org/wiki/Ni%C3%B1a
# ID: 451, Τίτλος: Michel Majerus, URL: https://en.wikipedia.org/wiki/Michel_Majerus
# ID: 456, Τίτλος: Tetrapteron palmeri, URL: https://en.wikipedia.org/wiki/Tetrapteron_palmeri
# ID: 467, Τίτλος: Vipera aspis francisciredi, URL: https://en.wikipedia.org/wiki/Vipera_aspis_francisciredi
# ID: 462, Τίτλος: Agnorhiza elata, URL: https://en.wikipedia.org/wiki/Agnorhiza_elata
# ID: 473, Τίτλος: Lyria vegai, URL: https://en.wikipedia.org/wiki/Lyria_vegai
# ID: 482, Τίτλος: Viola rubella, URL: https://en.wikipedia.org/wiki/Viola_rubella
# ID: 492, Τίτλος: 2018 American Athletic Conference Football Championship Game, URL: https://en.wikipedia.org/wiki/2018_American_Athletic_Conference_Football_Championship_Game
# ID: 506, Τίτλος: Panicum, URL: https://en.wikipedia.org/wiki/Panicum
# ID: 509, Τίτλος: Kazue Togasaki, URL: https://en.wikipedia.org/wiki/Kazue_Togasaki
# ID: 507, Τίτλος: 1894 Washington Senators season, URL: https://en.wikipedia.org/wiki/1894_Washington_Senators_season
# ID: 520, Τίτλος: Mustafa Kassem, URL: https://en.wikipedia.org/wiki/Mustafa_Kassem
# ID: 512, Τίτλος: Spencer Kieboom, URL: https://en.wikipedia.org/wiki/Spencer_Kieboom
# ID: 515, Τίτλος: List of Pittsburgh Pirates no-hitters, URL: https://en.wikipedia.org/wiki/List_of_Pittsburgh_Pirates_no-hitters
# ID: 518, Τίτλος: Stoney Knoll First Nation, URL: https://en.wikipedia.org/wiki/Stoney_Knoll_First_Nation
# ID: 532, Τίτλος: Grey rockcod, URL: https://en.wikipedia.org/wiki/Grey_rockcod
# ID: 535, Τίτλος: Richeza of Lotharingia, URL: https://en.wikipedia.org/wiki/Richeza_of_Lotharingia
# ID: 548, Τίτλος: Hopea johorensis, URL: https://en.wikipedia.org/wiki/Hopea_johorensis
# ID: 549, Τίτλος: Jabalpur–Bhusaval section, URL: https://en.wikipedia.org/wiki/Jabalpur%E2%80%93Bhusaval_section
# ID: 545, Τίτλος: Schistura altipedunculatus, URL: https://en.wikipedia.org/wiki/Schistura_altipedunculatus
# ID: 553, Τίτλος: Noelle Murray, URL: https://en.wikipedia.org/wiki/Noelle_Murray
# ID: 559, Τίτλος: La La La (LMFAO song), URL: https://en.wikipedia.org/wiki/La_La_La_(LMFAO_song)
# ID: 554, Τίτλος: Pseudosoloe, URL: https://en.wikipedia.org/wiki/Pseudosoloe
# ID: 562, Τίτλος: Basketball Löwen Braunschweig, URL: https://en.wikipedia.org/wiki/Basketball_L%C3%B6wen_Braunschweig
# ID: 567, Τίτλος: Viktor Meyer, URL: https://en.wikipedia.org/wiki/Viktor_Meyer
# ID: 565, Τίτλος: 2011 Australian Open – Wheelchair men's doubles, URL: https://en.wikipedia.org/wiki/2011_Australian_Open_%E2%80%93_Wheelchair_men's_doubles
# ID: 581, Τίτλος: Little Bucks, URL: https://en.wikipedia.org/wiki/Little_Bucks
# ID: 589, Τίτλος: Oskar Seyffert (classical scholar), URL: https://en.wikipedia.org/wiki/Oskar_Seyffert_(classical_scholar)
# ID: 597, Τίτλος: Danny Kopec, URL: https://en.wikipedia.org/wiki/Danny_Kopec
# ID: 605, Τίτλος: Senecio madagascariensis, URL: https://en.wikipedia.org/wiki/Senecio_madagascariensis
# ID: 607, Τίτλος: 2004 Wimbledon Championships – Mixed doubles, URL: https://en.wikipedia.org/wiki/2004_Wimbledon_Championships_%E2%80%93_Mixed_doubles
# ID: 637, Τίτλος: Pedetontus saltator, URL: https://en.wikipedia.org/wiki/Pedetontus_saltator
# ID: 638, Τίτλος: Scrobipalpa plesiopicta, URL: https://en.wikipedia.org/wiki/Scrobipalpa_plesiopicta
# ID: 647, Τίτλος: Johnsonville railway station, URL: https://en.wikipedia.org/wiki/Johnsonville_railway_station
# ID: 643, Τίτλος: 2007 Independence Bowl, URL: https://en.wikipedia.org/wiki/2007_Independence_Bowl
# ID: 642, Τίτλος: Nickel double salts, URL: https://en.wikipedia.org/wiki/Nickel_double_salts
# ID: 652, Τίτλος: Jane Castor, URL: https://en.wikipedia.org/wiki/Jane_Castor
# ID: 656, Τίτλος: Piano Trio No. 43 (Haydn), URL: https://en.wikipedia.org/wiki/Piano_Trio_No._43_(Haydn)
# ID: 651, Τίτλος: Rusty's Birthday, URL: https://en.wikipedia.org/wiki/Rusty's_Birthday
# ID: 662, Τίτλος: Vengeance (2001), URL: https://en.wikipedia.org/wiki/Vengeance_(2001)
# ID: 669, Τίτλος: High Elms Manor, URL: https://en.wikipedia.org/wiki/High_Elms_Manor
# ID: 661, Τίτλος: Costa Rica at the 2013 World Aquatics Championships, URL: https://en.wikipedia.org/wiki/Costa_Rica_at_the_2013_World_Aquatics_Championships
# ID: 678, Τίτλος: History of Rutgers University, URL: https://en.wikipedia.org/wiki/History_of_Rutgers_University
# ID: 677, Τίτλος: Angel Arribas Lopez, URL: https://en.wikipedia.org/wiki/Angel_Arribas_Lopez
# ID: 683, Τίτλος: Manok ng Bayan–SBP 3X3, URL: https://en.wikipedia.org/wiki/Manok_ng_Bayan%E2%80%93SBP_3X3
# ID: 686, Τίτλος: Welcome to Convenience Store, URL: https://en.wikipedia.org/wiki/Welcome_to_Convenience_Store
# ID: 688, Τίτλος: 2016 Milo Open Cali – Doubles, URL: https://en.wikipedia.org/wiki/2016_Milo_Open_Cali_%E2%80%93_Doubles
# ID: 690, Τίτλος: C. Harrison Mann, URL: https://en.wikipedia.org/wiki/C._Harrison_Mann
# ID: 692, Τίτλος: The Last Day (Doctor Who), URL: https://en.wikipedia.org/wiki/The_Last_Day_(Doctor_Who)
# ID: 693, Τίτλος: Eddie Miller (racing driver, born 1945), URL: https://en.wikipedia.org/wiki/Eddie_Miller_(racing_driver,_born_1945)
# ID: 691, Τίτλος: USS George Philip, URL: https://en.wikipedia.org/wiki/USS_George_Philip
# ID: 710, Τίτλος: Rasheed Kidwai, URL: https://en.wikipedia.org/wiki/Rasheed_Kidwai
# ID: 705, Τίτλος: Tillandsia limbata, URL: https://en.wikipedia.org/wiki/Tillandsia_limbata
# ID: 714, Τίτλος: Leo Zehntner, URL: https://en.wikipedia.org/wiki/Leo_Zehntner
# ID: 717, Τίτλος: Mythimna straminea, URL: https://en.wikipedia.org/wiki/Mythimna_straminea
# ID: 725, Τίτλος: Penn Incline, URL: https://en.wikipedia.org/wiki/Penn_Incline
# ID: 730, Τίτλος: Spirostachys africana, URL: https://en.wikipedia.org/wiki/Spirostachys_africana
# ID: 729, Τίτλος: Roger McGuinn & Band, URL: https://en.wikipedia.org/wiki/Roger_McGuinn_&_Band
# ID: 743, Τίτλος: 1986 FIFA World Cup, URL: https://en.wikipedia.org/wiki/1986_FIFA_World_Cup
# ID: 745, Τίτλος: Tomasz Kucharzewski, URL: https://en.wikipedia.org/wiki/Tomasz_Kucharzewski
# ID: 741, Τίτλος: Inline speed skating at the 2013 Bolivarian Games, URL: https://en.wikipedia.org/wiki/Inline_speed_skating_at_the_2013_Bolivarian_Games
# ID: 750, Τίτλος: Lipotriches edirisinghei, URL: https://en.wikipedia.org/wiki/Lipotriches_edirisinghei
# ID: 744, Τίτλος: 1985 Player's Canadian Open – Men's doubles, URL: https://en.wikipedia.org/wiki/1985_Player's_Canadian_Open_%E2%80%93_Men's_doubles
# ID: 755, Τίτλος: Sexual Assault Awareness Month, URL: https://en.wikipedia.org/wiki/Sexual_Assault_Awareness_Month
# ID: 760, Τίτλος: Agdistis malitiosa, URL: https://en.wikipedia.org/wiki/Agdistis_malitiosa
# ID: 766, Τίτλος: Diplostephium ericoides, URL: https://en.wikipedia.org/wiki/Diplostephium_ericoides
# ID: 765, Τίτλος: Gardner Green Stevens, URL: https://en.wikipedia.org/wiki/Gardner_Green_Stevens
# ID: 763, Τίτλος: Dolichopteryx, URL: https://en.wikipedia.org/wiki/Dolichopteryx
# ID: 771, Τίτλος: Quercus congesta, URL: https://en.wikipedia.org/wiki/Quercus_congesta
# ID: 776, Τίτλος: Victor Nehlig, URL: https://en.wikipedia.org/wiki/Victor_Nehlig
# ID: 788, Τίτλος: List of Singapore Open men's doubles champions, URL: https://en.wikipedia.org/wiki/List_of_Singapore_Open_men's_doubles_champions
# ID: 789, Τίτλος: Landau–Rohrbach railway, URL: https://en.wikipedia.org/wiki/Landau%E2%80%93Rohrbach_railway
# ID: 785, Τίτλος: Omoglymmius lederi, URL: https://en.wikipedia.org/wiki/Omoglymmius_lederi
# ID: 799, Τίτλος: Euphaedra preussi, URL: https://en.wikipedia.org/wiki/Euphaedra_preussi
# ID: 806, Τίτλος: Kelly Denton, URL: https://en.wikipedia.org/wiki/Kelly_Denton
# ID: 805, Τίτλος: Ulm–Augsburg railway, URL: https://en.wikipedia.org/wiki/Ulm%E2%80%93Augsburg_railway
# ID: 816, Τίτλος: Swedes, URL: https://en.wikipedia.org/wiki/Swedes
# ID: 829, Τίτλος: Misbehaviour (film), URL: https://en.wikipedia.org/wiki/Misbehaviour_(film)
# ID: 821, Τίτλος: Ethan Van Sciver, URL: https://en.wikipedia.org/wiki/Ethan_Van_Sciver
# ID: 849, Τίτλος: 2016 Rangitikei local elections, URL: https://en.wikipedia.org/wiki/2016_Rangitikei_local_elections
# ID: 861, Τίτλος: Trolley Books, URL: https://en.wikipedia.org/wiki/Trolley_Books
# ID: 866, Τίτλος: Bomb (tank), URL: https://en.wikipedia.org/wiki/Bomb_(tank)
# ID: 887, Τίτλος: Hippotion moorei, URL: https://en.wikipedia.org/wiki/Hippotion_moorei
# ID: 895, Τίτλος: Juncus nevadensis, URL: https://en.wikipedia.org/wiki/Juncus_nevadensis
# ID: 908, Τίτλος: Mary Whitwell Hale, URL: https://en.wikipedia.org/wiki/Mary_Whitwell_Hale
# ID: 901, Τίτλος: Antaeotricha lathiptila, URL: https://en.wikipedia.org/wiki/Antaeotricha_lathiptila
# ID: 927, Τίτλος: Midsummer Stakes, URL: https://en.wikipedia.org/wiki/Midsummer_Stakes
# ID: 948, Τίτλος: 2021 American Athletic Conference men's soccer tournament, URL: https://en.wikipedia.org/wiki/2021_American_Athletic_Conference_men's_soccer_tournament
# ID: 955, Τίτλος: Ubisoft Singapore, URL: https://en.wikipedia.org/wiki/Ubisoft_Singapore
# ID: 953, Τίτλος: Neusticurus medemi, URL: https://en.wikipedia.org/wiki/Neusticurus_medemi
# ID: 967, Τίτλος: Bill Mullahey, URL: https://en.wikipedia.org/wiki/Bill_Mullahey
# ID: 961, Τίτλος: Christopher Hilsenbeck, URL: https://en.wikipedia.org/wiki/Christopher_Hilsenbeck
# ID: 973, Τίτλος: Frederick Municipal Airport (Maryland), URL: https://en.wikipedia.org/wiki/Frederick_Municipal_Airport_(Maryland)
# ID: 971, Τίτλος: List of Phantom Thief Jeanne episodes, URL: https://en.wikipedia.org/wiki/List_of_Phantom_Thief_Jeanne_episodes
# ID: 989, Τίτλος: Pokataroo railway line, URL: https://en.wikipedia.org/wiki/Pokataroo_railway_line
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): open not christmas
# Βρέθηκαν 175 σχετικά έγγραφα:
#
# ID: 2, Τίτλος: New York State Canal Corporation, URL: https://en.wikipedia.org/wiki/New_York_State_Canal_Corporation
# ID: 17, Τίτλος: Michel Casseux, URL: https://en.wikipedia.org/wiki/Michel_Casseux
# ID: 15, Τίτλος: Smidtia, URL: https://en.wikipedia.org/wiki/Smidtia
# ID: 25, Τίτλος: Bekim Erkoceviç, URL: https://en.wikipedia.org/wiki/Bekim_Erkocevi%C3%A7
# ID: 40, Τίτλος: Bian stones, URL: https://en.wikipedia.org/wiki/Bian_stones
# ID: 32, Τίτλος: Cacozelia elegans, URL: https://en.wikipedia.org/wiki/Cacozelia_elegans
# ID: 39, Τίτλος: Devario manipurensis, URL: https://en.wikipedia.org/wiki/Devario_manipurensis
# ID: 47, Τίτλος: Killzone 3, URL: https://en.wikipedia.org/wiki/Killzone_3
# ID: 44, Τίτλος: Cologne Stadtbahn, URL: https://en.wikipedia.org/wiki/Cologne_Stadtbahn
# ID: 49, Τίτλος: Mysouffa, URL: https://en.wikipedia.org/wiki/Mysouffa
# ID: 54, Τίτλος: Conical combination, URL: https://en.wikipedia.org/wiki/Conical_combination
# ID: 57, Τίτλος: Dendrobium dickasonii, URL: https://en.wikipedia.org/wiki/Dendrobium_dickasonii
# ID: 79, Τίτλος: Urgleptes amplicollis, URL: https://en.wikipedia.org/wiki/Urgleptes_amplicollis
# ID: 92, Τίτλος: Aglossosia semisericea, URL: https://en.wikipedia.org/wiki/Aglossosia_semisericea
# ID: 95, Τίτλος: Elora Rocks, URL: https://en.wikipedia.org/wiki/Elora_Rocks
# ID: 98, Τίτλος: Pseudanthias pleurotaenia, URL: https://en.wikipedia.org/wiki/Pseudanthias_pleurotaenia
# ID: 111, Τίτλος: Rubis Energy Kenya, URL: https://en.wikipedia.org/wiki/Rubis_Energy_Kenya
# ID: 114, Τίτλος: 2019–20 Levante UD season, URL: https://en.wikipedia.org/wiki/2019%E2%80%9320_Levante_UD_season
# ID: 129, Τίτλος: Disability fraud, URL: https://en.wikipedia.org/wiki/Disability_fraud
# ID: 126, Τίτλος: Metsatöll, URL: https://en.wikipedia.org/wiki/Metsat%C3%B6ll
# ID: 125, Τίτλος: 1938 VPI Gobblers football team, URL: https://en.wikipedia.org/wiki/1938_VPI_Gobblers_football_team
# ID: 134, Τίτλος: Jacopo Tiepolo, URL: https://en.wikipedia.org/wiki/Jacopo_Tiepolo
# ID: 140, Τίτλος: Didymocyrtidium, URL: https://en.wikipedia.org/wiki/Didymocyrtidium
# ID: 138, Τίτλος: Andrew Campbell (golfer), URL: https://en.wikipedia.org/wiki/Andrew_Campbell_(golfer)
# ID: 131, Τίτλος: Flavobacterium cucumis, URL: https://en.wikipedia.org/wiki/Flavobacterium_cucumis
# ID: 155, Τίτλος: List of U.S. Highways in Montana, URL: https://en.wikipedia.org/wiki/List_of_U.S._Highways_in_Montana
# ID: 168, Τίτλος: Before the Law, URL: https://en.wikipedia.org/wiki/Before_the_Law
# ID: 166, Τίτλος: Uresiphita ornithopteralis, URL: https://en.wikipedia.org/wiki/Uresiphita_ornithopteralis
# ID: 167, Τίτλος: Dardanelle pontoon bridge, URL: https://en.wikipedia.org/wiki/Dardanelle_pontoon_bridge
# ID: 172, Τίτλος: Screenplay, URL: https://en.wikipedia.org/wiki/Screenplay
# ID: 177, Τίτλος: Zobellella denitrificans, URL: https://en.wikipedia.org/wiki/Zobellella_denitrificans
# ID: 181, Τίτλος: 1750, URL: https://en.wikipedia.org/wiki/1750
# ID: 186, Τίτλος: Water by the Spoonful, URL: https://en.wikipedia.org/wiki/Water_by_the_Spoonful
# ID: 183, Τίτλος: Acacia decurrens, URL: https://en.wikipedia.org/wiki/Acacia_decurrens
# ID: 197, Τίτλος: Normal schools in the United States, URL: https://en.wikipedia.org/wiki/Normal_schools_in_the_United_States
# ID: 194, Τίτλος: 1910 Vermont Green and Gold football team, URL: https://en.wikipedia.org/wiki/1910_Vermont_Green_and_Gold_football_team
# ID: 200, Τίτλος: Platform Prize, URL: https://en.wikipedia.org/wiki/Platform_Prize
# ID: 196, Τίτλος: Paraguayan punaré, URL: https://en.wikipedia.org/wiki/Paraguayan_punar%C3%A9
# ID: 192, Τίτλος: Third Shadow Cabinet of Andrew RT Davies, URL: https://en.wikipedia.org/wiki/Third_Shadow_Cabinet_of_Andrew_RT_Davies
# ID: 206, Τίτλος: Spirituals, URL: https://en.wikipedia.org/wiki/Spirituals
# ID: 208, Τίτλος: 2014 Corpus Christi Fury season, URL: https://en.wikipedia.org/wiki/2014_Corpus_Christi_Fury_season
# ID: 204, Τίτλος: Bartonella heixiaziensis, URL: https://en.wikipedia.org/wiki/Bartonella_heixiaziensis
# ID: 219, Τίτλος: Neolophosia, URL: https://en.wikipedia.org/wiki/Neolophosia
# ID: 220, Τίτλος: Agreement on Port State Measures to Prevent, Deter and Eliminate Illegal, Unreported and Unregulated Fishing, URL: https://en.wikipedia.org/wiki/Agreement_on_Port_State_Measures_to_Prevent,_Deter_and_Eliminate_Illegal,_Unreported_and_Unregulated_Fishing
# ID: 232, Τίτλος: Sisyrinchium funereum, URL: https://en.wikipedia.org/wiki/Sisyrinchium_funereum
# ID: 236, Τίτλος: Heliogomphus ceylonicus, URL: https://en.wikipedia.org/wiki/Heliogomphus_ceylonicus
# ID: 250, Τίτλος: Ancylosis leucocephala, URL: https://en.wikipedia.org/wiki/Ancylosis_leucocephala
# ID: 245, Τίτλος: United Supermarkets, URL: https://en.wikipedia.org/wiki/United_Supermarkets
# ID: 242, Τίτλος: Garth Dawley, URL: https://en.wikipedia.org/wiki/Garth_Dawley
# ID: 251, Τίτλος: Kiss Me, Kill Me, URL: https://en.wikipedia.org/wiki/Kiss_Me,_Kill_Me
# ID: 262, Τίτλος: List of neighbourhoods of Kollam, URL: https://en.wikipedia.org/wiki/List_of_neighbourhoods_of_Kollam
# ID: 267, Τίτλος: Paan Singh Tomar, URL: https://en.wikipedia.org/wiki/Paan_Singh_Tomar
# ID: 265, Τίτλος: Scleronema (plant), URL: https://en.wikipedia.org/wiki/Scleronema_(plant)
# ID: 261, Τίτλος: Conotalis aurantifascia, URL: https://en.wikipedia.org/wiki/Conotalis_aurantifascia
# ID: 276, Τίτλος: Paramysis nouveli, URL: https://en.wikipedia.org/wiki/Paramysis_nouveli
# ID: 277, Τίτλος: Cystoporida, URL: https://en.wikipedia.org/wiki/Cystoporida
# ID: 283, Τίτλος: 1956 Palanca Awards, URL: https://en.wikipedia.org/wiki/1956_Palanca_Awards
# ID: 281, Τίτλος: 2024 Córdoba Open, URL: https://en.wikipedia.org/wiki/2024_C%C3%B3rdoba_Open
# ID: 298, Τίτλος: Iskandar Widjaja, URL: https://en.wikipedia.org/wiki/Iskandar_Widjaja
# ID: 299, Τίτλος: 2010 in association football, URL: https://en.wikipedia.org/wiki/2010_in_association_football
# ID: 309, Τίτλος: NASDAQ futures, URL: https://en.wikipedia.org/wiki/NASDAQ_futures
# ID: 308, Τίτλος: Elegantogyaritus wakaharai, URL: https://en.wikipedia.org/wiki/Elegantogyaritus_wakaharai
# ID: 307, Τίτλος: HB Ice Cream, URL: https://en.wikipedia.org/wiki/HB_Ice_Cream
# ID: 322, Τίτλος: Sergei Movsesian, URL: https://en.wikipedia.org/wiki/Sergei_Movsesian
# ID: 340, Τίτλος: Stictogryllacris quadripunctata, URL: https://en.wikipedia.org/wiki/Stictogryllacris_quadripunctata
# ID: 342, Τίτλος: Fantastic Planet (Failure album), URL: https://en.wikipedia.org/wiki/Fantastic_Planet_(Failure_album)
# ID: 348, Τίτλος: Selenogyrus brunneus, URL: https://en.wikipedia.org/wiki/Selenogyrus_brunneus
# ID: 347, Τίτλος: Renodesta ramsdalei, URL: https://en.wikipedia.org/wiki/Renodesta_ramsdalei
# ID: 364, Τίτλος: Khabur ware, URL: https://en.wikipedia.org/wiki/Khabur_ware
# ID: 369, Τίτλος: Pakistan Open, URL: https://en.wikipedia.org/wiki/Pakistan_Open
# ID: 368, Τίτλος: Do Ngak Kunphen Ling Tibetan Buddhist Center for Universal Peace, URL: https://en.wikipedia.org/wiki/Do_Ngak_Kunphen_Ling_Tibetan_Buddhist_Center_for_Universal_Peace
# ID: 370, Τίτλος: Sarojini Sahoo, URL: https://en.wikipedia.org/wiki/Sarojini_Sahoo
# ID: 371, Τίτλος: Symphlebia indistincta, URL: https://en.wikipedia.org/wiki/Symphlebia_indistincta
# ID: 379, Τίτλος: Trypanaresta delicatella, URL: https://en.wikipedia.org/wiki/Trypanaresta_delicatella
# ID: 395, Τίτλος: Athous, URL: https://en.wikipedia.org/wiki/Athous
# ID: 394, Τίτλος: Hesperentomon kuratai, URL: https://en.wikipedia.org/wiki/Hesperentomon_kuratai
# ID: 420, Τίτλος: Jim Kaat, URL: https://en.wikipedia.org/wiki/Jim_Kaat
# ID: 426, Τίτλος: Mark Scatterday, URL: https://en.wikipedia.org/wiki/Mark_Scatterday
# ID: 443, Τίτλος: Rachel Mason, URL: https://en.wikipedia.org/wiki/Rachel_Mason
# ID: 449, Τίτλος: Chaudhary Charan Singh Haryana Agricultural University Sports Complex, URL: https://en.wikipedia.org/wiki/Chaudhary_Charan_Singh_Haryana_Agricultural_University_Sports_Complex
# ID: 454, Τίτλος: Niña, URL: https://en.wikipedia.org/wiki/Ni%C3%B1a
# ID: 451, Τίτλος: Michel Majerus, URL: https://en.wikipedia.org/wiki/Michel_Majerus
# ID: 456, Τίτλος: Tetrapteron palmeri, URL: https://en.wikipedia.org/wiki/Tetrapteron_palmeri
# ID: 467, Τίτλος: Vipera aspis francisciredi, URL: https://en.wikipedia.org/wiki/Vipera_aspis_francisciredi
# ID: 462, Τίτλος: Agnorhiza elata, URL: https://en.wikipedia.org/wiki/Agnorhiza_elata
# ID: 473, Τίτλος: Lyria vegai, URL: https://en.wikipedia.org/wiki/Lyria_vegai
# ID: 482, Τίτλος: Viola rubella, URL: https://en.wikipedia.org/wiki/Viola_rubella
# ID: 492, Τίτλος: 2018 American Athletic Conference Football Championship Game, URL: https://en.wikipedia.org/wiki/2018_American_Athletic_Conference_Football_Championship_Game
# ID: 506, Τίτλος: Panicum, URL: https://en.wikipedia.org/wiki/Panicum
# ID: 509, Τίτλος: Kazue Togasaki, URL: https://en.wikipedia.org/wiki/Kazue_Togasaki
# ID: 507, Τίτλος: 1894 Washington Senators season, URL: https://en.wikipedia.org/wiki/1894_Washington_Senators_season
# ID: 520, Τίτλος: Mustafa Kassem, URL: https://en.wikipedia.org/wiki/Mustafa_Kassem
# ID: 512, Τίτλος: Spencer Kieboom, URL: https://en.wikipedia.org/wiki/Spencer_Kieboom
# ID: 515, Τίτλος: List of Pittsburgh Pirates no-hitters, URL: https://en.wikipedia.org/wiki/List_of_Pittsburgh_Pirates_no-hitters
# ID: 518, Τίτλος: Stoney Knoll First Nation, URL: https://en.wikipedia.org/wiki/Stoney_Knoll_First_Nation
# ID: 532, Τίτλος: Grey rockcod, URL: https://en.wikipedia.org/wiki/Grey_rockcod
# ID: 535, Τίτλος: Richeza of Lotharingia, URL: https://en.wikipedia.org/wiki/Richeza_of_Lotharingia
# ID: 548, Τίτλος: Hopea johorensis, URL: https://en.wikipedia.org/wiki/Hopea_johorensis
# ID: 549, Τίτλος: Jabalpur–Bhusaval section, URL: https://en.wikipedia.org/wiki/Jabalpur%E2%80%93Bhusaval_section
# ID: 545, Τίτλος: Schistura altipedunculatus, URL: https://en.wikipedia.org/wiki/Schistura_altipedunculatus
# ID: 553, Τίτλος: Noelle Murray, URL: https://en.wikipedia.org/wiki/Noelle_Murray
# ID: 559, Τίτλος: La La La (LMFAO song), URL: https://en.wikipedia.org/wiki/La_La_La_(LMFAO_song)
# ID: 554, Τίτλος: Pseudosoloe, URL: https://en.wikipedia.org/wiki/Pseudosoloe
# ID: 562, Τίτλος: Basketball Löwen Braunschweig, URL: https://en.wikipedia.org/wiki/Basketball_L%C3%B6wen_Braunschweig
# ID: 567, Τίτλος: Viktor Meyer, URL: https://en.wikipedia.org/wiki/Viktor_Meyer
# ID: 565, Τίτλος: 2011 Australian Open – Wheelchair men's doubles, URL: https://en.wikipedia.org/wiki/2011_Australian_Open_%E2%80%93_Wheelchair_men's_doubles
# ID: 581, Τίτλος: Little Bucks, URL: https://en.wikipedia.org/wiki/Little_Bucks
# ID: 589, Τίτλος: Oskar Seyffert (classical scholar), URL: https://en.wikipedia.org/wiki/Oskar_Seyffert_(classical_scholar)
# ID: 597, Τίτλος: Danny Kopec, URL: https://en.wikipedia.org/wiki/Danny_Kopec
# ID: 605, Τίτλος: Senecio madagascariensis, URL: https://en.wikipedia.org/wiki/Senecio_madagascariensis
# ID: 607, Τίτλος: 2004 Wimbledon Championships – Mixed doubles, URL: https://en.wikipedia.org/wiki/2004_Wimbledon_Championships_%E2%80%93_Mixed_doubles
# ID: 637, Τίτλος: Pedetontus saltator, URL: https://en.wikipedia.org/wiki/Pedetontus_saltator
# ID: 638, Τίτλος: Scrobipalpa plesiopicta, URL: https://en.wikipedia.org/wiki/Scrobipalpa_plesiopicta
# ID: 647, Τίτλος: Johnsonville railway station, URL: https://en.wikipedia.org/wiki/Johnsonville_railway_station
# ID: 643, Τίτλος: 2007 Independence Bowl, URL: https://en.wikipedia.org/wiki/2007_Independence_Bowl
# ID: 642, Τίτλος: Nickel double salts, URL: https://en.wikipedia.org/wiki/Nickel_double_salts
# ID: 652, Τίτλος: Jane Castor, URL: https://en.wikipedia.org/wiki/Jane_Castor
# ID: 656, Τίτλος: Piano Trio No. 43 (Haydn), URL: https://en.wikipedia.org/wiki/Piano_Trio_No._43_(Haydn)
# ID: 651, Τίτλος: Rusty's Birthday, URL: https://en.wikipedia.org/wiki/Rusty's_Birthday
# ID: 662, Τίτλος: Vengeance (2001), URL: https://en.wikipedia.org/wiki/Vengeance_(2001)
# ID: 669, Τίτλος: High Elms Manor, URL: https://en.wikipedia.org/wiki/High_Elms_Manor
# ID: 661, Τίτλος: Costa Rica at the 2013 World Aquatics Championships, URL: https://en.wikipedia.org/wiki/Costa_Rica_at_the_2013_World_Aquatics_Championships
# ID: 678, Τίτλος: History of Rutgers University, URL: https://en.wikipedia.org/wiki/History_of_Rutgers_University
# ID: 677, Τίτλος: Angel Arribas Lopez, URL: https://en.wikipedia.org/wiki/Angel_Arribas_Lopez
# ID: 683, Τίτλος: Manok ng Bayan–SBP 3X3, URL: https://en.wikipedia.org/wiki/Manok_ng_Bayan%E2%80%93SBP_3X3
# ID: 686, Τίτλος: Welcome to Convenience Store, URL: https://en.wikipedia.org/wiki/Welcome_to_Convenience_Store
# ID: 688, Τίτλος: 2016 Milo Open Cali – Doubles, URL: https://en.wikipedia.org/wiki/2016_Milo_Open_Cali_%E2%80%93_Doubles
# ID: 690, Τίτλος: C. Harrison Mann, URL: https://en.wikipedia.org/wiki/C._Harrison_Mann
# ID: 692, Τίτλος: The Last Day (Doctor Who), URL: https://en.wikipedia.org/wiki/The_Last_Day_(Doctor_Who)
# ID: 693, Τίτλος: Eddie Miller (racing driver, born 1945), URL: https://en.wikipedia.org/wiki/Eddie_Miller_(racing_driver,_born_1945)
# ID: 691, Τίτλος: USS George Philip, URL: https://en.wikipedia.org/wiki/USS_George_Philip
# ID: 710, Τίτλος: Rasheed Kidwai, URL: https://en.wikipedia.org/wiki/Rasheed_Kidwai
# ID: 705, Τίτλος: Tillandsia limbata, URL: https://en.wikipedia.org/wiki/Tillandsia_limbata
# ID: 714, Τίτλος: Leo Zehntner, URL: https://en.wikipedia.org/wiki/Leo_Zehntner
# ID: 717, Τίτλος: Mythimna straminea, URL: https://en.wikipedia.org/wiki/Mythimna_straminea
# ID: 725, Τίτλος: Penn Incline, URL: https://en.wikipedia.org/wiki/Penn_Incline
# ID: 730, Τίτλος: Spirostachys africana, URL: https://en.wikipedia.org/wiki/Spirostachys_africana
# ID: 729, Τίτλος: Roger McGuinn & Band, URL: https://en.wikipedia.org/wiki/Roger_McGuinn_&_Band
# ID: 743, Τίτλος: 1986 FIFA World Cup, URL: https://en.wikipedia.org/wiki/1986_FIFA_World_Cup
# ID: 745, Τίτλος: Tomasz Kucharzewski, URL: https://en.wikipedia.org/wiki/Tomasz_Kucharzewski
# ID: 741, Τίτλος: Inline speed skating at the 2013 Bolivarian Games, URL: https://en.wikipedia.org/wiki/Inline_speed_skating_at_the_2013_Bolivarian_Games
# ID: 750, Τίτλος: Lipotriches edirisinghei, URL: https://en.wikipedia.org/wiki/Lipotriches_edirisinghei
# ID: 744, Τίτλος: 1985 Player's Canadian Open – Men's doubles, URL: https://en.wikipedia.org/wiki/1985_Player's_Canadian_Open_%E2%80%93_Men's_doubles
# ID: 755, Τίτλος: Sexual Assault Awareness Month, URL: https://en.wikipedia.org/wiki/Sexual_Assault_Awareness_Month
# ID: 760, Τίτλος: Agdistis malitiosa, URL: https://en.wikipedia.org/wiki/Agdistis_malitiosa
# ID: 766, Τίτλος: Diplostephium ericoides, URL: https://en.wikipedia.org/wiki/Diplostephium_ericoides
# ID: 765, Τίτλος: Gardner Green Stevens, URL: https://en.wikipedia.org/wiki/Gardner_Green_Stevens
# ID: 763, Τίτλος: Dolichopteryx, URL: https://en.wikipedia.org/wiki/Dolichopteryx
# ID: 771, Τίτλος: Quercus congesta, URL: https://en.wikipedia.org/wiki/Quercus_congesta
# ID: 776, Τίτλος: Victor Nehlig, URL: https://en.wikipedia.org/wiki/Victor_Nehlig
# ID: 788, Τίτλος: List of Singapore Open men's doubles champions, URL: https://en.wikipedia.org/wiki/List_of_Singapore_Open_men's_doubles_champions
# ID: 789, Τίτλος: Landau–Rohrbach railway, URL: https://en.wikipedia.org/wiki/Landau%E2%80%93Rohrbach_railway
# ID: 785, Τίτλος: Omoglymmius lederi, URL: https://en.wikipedia.org/wiki/Omoglymmius_lederi
# ID: 799, Τίτλος: Euphaedra preussi, URL: https://en.wikipedia.org/wiki/Euphaedra_preussi
# ID: 806, Τίτλος: Kelly Denton, URL: https://en.wikipedia.org/wiki/Kelly_Denton
# ID: 805, Τίτλος: Ulm–Augsburg railway, URL: https://en.wikipedia.org/wiki/Ulm%E2%80%93Augsburg_railway
# ID: 816, Τίτλος: Swedes, URL: https://en.wikipedia.org/wiki/Swedes
# ID: 829, Τίτλος: Misbehaviour (film), URL: https://en.wikipedia.org/wiki/Misbehaviour_(film)
# ID: 821, Τίτλος: Ethan Van Sciver, URL: https://en.wikipedia.org/wiki/Ethan_Van_Sciver
# ID: 849, Τίτλος: 2016 Rangitikei local elections, URL: https://en.wikipedia.org/wiki/2016_Rangitikei_local_elections
# ID: 861, Τίτλος: Trolley Books, URL: https://en.wikipedia.org/wiki/Trolley_Books
# ID: 866, Τίτλος: Bomb (tank), URL: https://en.wikipedia.org/wiki/Bomb_(tank)
# ID: 887, Τίτλος: Hippotion moorei, URL: https://en.wikipedia.org/wiki/Hippotion_moorei
# ID: 895, Τίτλος: Juncus nevadensis, URL: https://en.wikipedia.org/wiki/Juncus_nevadensis
# ID: 908, Τίτλος: Mary Whitwell Hale, URL: https://en.wikipedia.org/wiki/Mary_Whitwell_Hale
# ID: 901, Τίτλος: Antaeotricha lathiptila, URL: https://en.wikipedia.org/wiki/Antaeotricha_lathiptila
# ID: 927, Τίτλος: Midsummer Stakes, URL: https://en.wikipedia.org/wiki/Midsummer_Stakes
# ID: 948, Τίτλος: 2021 American Athletic Conference men's soccer tournament, URL: https://en.wikipedia.org/wiki/2021_American_Athletic_Conference_men's_soccer_tournament
# ID: 955, Τίτλος: Ubisoft Singapore, URL: https://en.wikipedia.org/wiki/Ubisoft_Singapore
# ID: 953, Τίτλος: Neusticurus medemi, URL: https://en.wikipedia.org/wiki/Neusticurus_medemi
# ID: 967, Τίτλος: Bill Mullahey, URL: https://en.wikipedia.org/wiki/Bill_Mullahey
# ID: 961, Τίτλος: Christopher Hilsenbeck, URL: https://en.wikipedia.org/wiki/Christopher_Hilsenbeck
# ID: 973, Τίτλος: Frederick Municipal Airport (Maryland), URL: https://en.wikipedia.org/wiki/Frederick_Municipal_Airport_(Maryland)
# ID: 971, Τίτλος: List of Phantom Thief Jeanne episodes, URL: https://en.wikipedia.org/wiki/List_of_Phantom_Thief_Jeanne_episodes
# ID: 989, Τίτλος: Pokataroo railway line, URL: https://en.wikipedia.org/wiki/Pokataroo_railway_line
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): christmas
# Βρέθηκαν 26 σχετικά έγγραφα:
#
# ID: 1, Τίτλος: List of animal actors, URL: https://en.wikipedia.org/wiki/List_of_animal_actors
# ID: 4, Τίτλος: Sikh culture, URL: https://en.wikipedia.org/wiki/Sikh_culture
# ID: 116, Τίτλος: Cindy Williams, URL: https://en.wikipedia.org/wiki/Cindy_Williams
# ID: 152, Τίτλος: Denise Boutte, URL: https://en.wikipedia.org/wiki/Denise_Boutte
# ID: 167, Τίτλος: Dardanelle pontoon bridge, URL: https://en.wikipedia.org/wiki/Dardanelle_pontoon_bridge
# ID: 243, Τίτλος: Dominic Aitchison, URL: https://en.wikipedia.org/wiki/Dominic_Aitchison
# ID: 350, Τίτλος: Moon McDare, URL: https://en.wikipedia.org/wiki/Moon_McDare
# ID: 355, Τίτλος: F. Burge Griswold, URL: https://en.wikipedia.org/wiki/F._Burge_Griswold
# ID: 388, Τίτλος: Randy Harrison, URL: https://en.wikipedia.org/wiki/Randy_Harrison
# ID: 431, Τίτλος: Chouriço doce, URL: https://en.wikipedia.org/wiki/Chouri%C3%A7o_doce
# ID: 441, Τίτλος: 2010 in British music charts, URL: https://en.wikipedia.org/wiki/2010_in_British_music_charts
# ID: 496, Τίτλος: Bodybuilding in India, URL: https://en.wikipedia.org/wiki/Bodybuilding_in_India
# ID: 526, Τίτλος: Bob Segarini, URL: https://en.wikipedia.org/wiki/Bob_Segarini
# ID: 539, Τίτλος: David Alpay, URL: https://en.wikipedia.org/wiki/David_Alpay
# ID: 535, Τίτλος: Richeza of Lotharingia, URL: https://en.wikipedia.org/wiki/Richeza_of_Lotharingia
# ID: 578, Τίτλος: WMXW, URL: https://en.wikipedia.org/wiki/WMXW
# ID: 576, Τίτλος: Ho-Sung Pak, URL: https://en.wikipedia.org/wiki/Ho-Sung_Pak
# ID: 622, Τίτλος: Hulda of Holland, URL: https://en.wikipedia.org/wiki/Hulda_of_Holland
# ID: 644, Τίτλος: Fok_It, URL: https://en.wikipedia.org/wiki/Fok_It
# ID: 692, Τίτλος: The Last Day (Doctor Who), URL: https://en.wikipedia.org/wiki/The_Last_Day_(Doctor_Who)
# ID: 728, Τίτλος: Mirror Mirror (Diana Ross song), URL: https://en.wikipedia.org/wiki/Mirror_Mirror_(Diana_Ross_song)
# ID: 769, Τίτλος: Slaxx, URL: https://en.wikipedia.org/wiki/Slaxx
# ID: 834, Τίτλος: June Allyson, URL: https://en.wikipedia.org/wiki/June_Allyson
# ID: 902, Τίτλος: Domino (Jessie J song), URL: https://en.wikipedia.org/wiki/Domino_(Jessie_J_song)
# ID: 908, Τίτλος: Mary Whitwell Hale, URL: https://en.wikipedia.org/wiki/Mary_Whitwell_Hale
# ID: 956, Τίτλος: Pirate King (novel), URL: https://en.wikipedia.org/wiki/Pirate_King_(novel)
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): exit
# Τερματισμός αναζήτησης.

# %% [markdown]
# #### β) Κατάταξη αποτελεσμάτων (Ranking):

# %%
# !pip install scikit-learn rank-bm25

from sklearn.feature_extraction.text import TfidfVectorizer
from rank_bm25 import BM25Okapi
import numpy as np

# Προετοιμασία δεδομένων για διαφορετικούς αλγορίθμους
corpus = [doc['Processed_Body'] for doc in documents]

# 1. TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)

# 2. BM25
bm25 = BM25Okapi([doc.split() for doc in corpus])

# Υπολογισμός κατάταξης με διαφορετικούς αλγορίθμους
def rank_results(query, algorithm="TF-IDF"):
    query_processed = ' '.join(process_query(query))
    
    if algorithm == "TF-IDF":
        # Υπολογισμός σχετικότητας με βάση το TF-IDF
        query_vector = tfidf_vectorizer.transform([query_processed])
        scores = np.dot(tfidf_matrix, query_vector.T).toarray().flatten()
        ranked_indices = np.argsort(-scores)
    
    elif algorithm == "BM25":
        # Υπολογισμός σχετικότητας με βάση το BM25
        scores = bm25.get_scores(query_processed.split())
        ranked_indices = np.argsort(-scores)
    
    elif algorithm == "VSM":
        # Χρήση TF-IDF ως βάση για VSM
        query_vector = tfidf_vectorizer.transform([query_processed])
        scores = np.dot(tfidf_matrix, query_vector.T).toarray().flatten()
        normalized_scores = scores / np.linalg.norm(scores)
        ranked_indices = np.argsort(-normalized_scores)
    
    else:
        raise ValueError("Μη έγκυρος αλγόριθμος. Επιλέξτε 'TF-IDF', 'BM25' ή 'VSM'.")
    
    # Επιστροφή ταξινομημένων αποτελεσμάτων
    return [(documents[idx]['ID'], scores[idx]) for idx in ranked_indices if scores[idx] > 0]

# Διαδραστική αναζήτηση με επιλογή αλγορίθμου
while True:
    query = input("Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): ").strip()
    if query.lower() == 'exit':
        print("Τερματισμός αναζήτησης.")
        break
    
    algorithm = input("Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): ").strip().upper()
    try:
        ranked_results = rank_results(query, algorithm)
        if ranked_results:
            print(f"Βρέθηκαν {len(ranked_results)} σχετικά έγγραφα με τον αλγόριθμο {algorithm}:\n")
            for rank, (doc_id, score) in enumerate(ranked_results[:10], start=1):
                doc = next((d for d in documents if d['ID'] == doc_id), None)
                print(f"{rank}. ID: {doc['ID']}, Τίτλος: {doc['Title']}, Σκορ: {score:.4f}, URL: {doc['URL']}")
        else:
            print("Δε βρέθηκαν σχετικά έγγραφα.")
    except ValueError as e:
        print(e)
# Out:
# Requirement already satisfied: scikit-learn in c:\users\agram\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: rank-bm25 in c:\users\agram\anaconda3\lib\site-packages (0.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\agram\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\agram\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\agram\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\agram\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): Israeli writer
# Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): Animal
# Μη έγκυρος αλγόριθμος. Επιλέξτε 'TF-IDF', 'BM25' ή 'VSM'.
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): Israeli writer
# Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): TF-IDF
# Βρέθηκαν 54 σχετικά έγγραφα με τον αλγόριθμο TF-IDF:
#
# 1. ID: 831, Τίτλος: Rescue of Ori Megidish, Σκορ: 0.3900, URL: https://en.wikipedia.org/wiki/Rescue_of_Ori_Megidish
# 2. ID: 202, Τίτλος: Ephraim (given name), Σκορ: 0.2411, URL: https://en.wikipedia.org/wiki/Ephraim_(given_name)
# 3. ID: 3, Τίτλος: Meir Shalev, Σκορ: 0.1678, URL: https://en.wikipedia.org/wiki/Meir_Shalev
# 4. ID: 533, Τίτλος: North Yemen at the 1988 Summer Olympics, Σκορ: 0.0809, URL: https://en.wikipedia.org/wiki/North_Yemen_at_the_1988_Summer_Olympics
# 5. ID: 271, Τίτλος: Ryōzō Nagashima, Σκορ: 0.0793, URL: https://en.wikipedia.org/wiki/Ry%C5%8Dz%C5%8D_Nagashima
# 6. ID: 792, Τίτλος: Mario Bellatin, Σκορ: 0.0725, URL: https://en.wikipedia.org/wiki/Mario_Bellatin
# 7. ID: 929, Τίτλος: Saifuddin Jalal, Σκορ: 0.0673, URL: https://en.wikipedia.org/wiki/Saifuddin_Jalal
# 8. ID: 798, Τίτλος: Ana María Simo, Σκορ: 0.0600, URL: https://en.wikipedia.org/wiki/Ana_Mar%C3%ADa_Simo
# 9. ID: 172, Τίτλος: Screenplay, Σκορ: 0.0591, URL: https://en.wikipedia.org/wiki/Screenplay
# 10. ID: 356, Τίτλος: Colin Jackson (politician), Σκορ: 0.0589, URL: https://en.wikipedia.org/wiki/Colin_Jackson_(politician)
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): animal actors
# Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): BM25
# Βρέθηκαν 81 σχετικά έγγραφα με τον αλγόριθμο BM25:
#
# 1. ID: 686, Τίτλος: Welcome to Convenience Store, Σκορ: 8.7201, URL: https://en.wikipedia.org/wiki/Welcome_to_Convenience_Store
# 2. ID: 1, Τίτλος: List of animal actors, Σκορ: 8.3095, URL: https://en.wikipedia.org/wiki/List_of_animal_actors
# 3. ID: 971, Τίτλος: List of Phantom Thief Jeanne episodes, Σκορ: 7.7880, URL: https://en.wikipedia.org/wiki/List_of_Phantom_Thief_Jeanne_episodes
# 4. ID: 240, Τίτλος: Wildlife Services, Σκορ: 6.7997, URL: https://en.wikipedia.org/wiki/Wildlife_Services
# 5. ID: 644, Τίτλος: Fok_It, Σκορ: 6.6457, URL: https://en.wikipedia.org/wiki/Fok_It
# 6. ID: 251, Τίτλος: Kiss Me, Kill Me, Σκορ: 6.5310, URL: https://en.wikipedia.org/wiki/Kiss_Me,_Kill_Me
# 7. ID: 202, Τίτλος: Ephraim (given name), Σκορ: 6.4315, URL: https://en.wikipedia.org/wiki/Ephraim_(given_name)
# 8. ID: 434, Τίτλος: Yamanaka, Σκορ: 6.0580, URL: https://en.wikipedia.org/wiki/Yamanaka
# 9. ID: 576, Τίτλος: Ho-Sung Pak, Σκορ: 6.0070, URL: https://en.wikipedia.org/wiki/Ho-Sung_Pak
# 10. ID: 106, Τίτλος: Armando Goyena, Σκορ: 5.9012, URL: https://en.wikipedia.org/wiki/Armando_Goyena
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): US Army general
# Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): VSM
# Βρέθηκαν 296 σχετικά έγγραφα με τον αλγόριθμο VSM:
#
# 1. ID: 155, Τίτλος: List of U.S. Highways in Montana, Σκορ: 0.3639, URL: https://en.wikipedia.org/wiki/List_of_U.S._Highways_in_Montana
# 2. ID: 10, Τίτλος: John S. Kolasheski, Σκορ: 0.3244, URL: https://en.wikipedia.org/wiki/John_S._Kolasheski
# 3. ID: 107, Τίτλος: 2017 FAM Youth Championship, Σκορ: 0.1501, URL: https://en.wikipedia.org/wiki/2017_FAM_Youth_Championship
# 4. ID: 476, Τίτλος: Salisbury Bypass, Σκορ: 0.1322, URL: https://en.wikipedia.org/wiki/Salisbury_Bypass
# 5. ID: 138, Τίτλος: Andrew Campbell (golfer), Σκορ: 0.1233, URL: https://en.wikipedia.org/wiki/Andrew_Campbell_(golfer)
# 6. ID: 43, Τίτλος: 2005 term United States Supreme Court opinions of John Paul Stevens, Σκορ: 0.1152, URL: https://en.wikipedia.org/wiki/2005_term_United_States_Supreme_Court_opinions_of_John_Paul_Stevens
# 7. ID: 18, Τίτλος: Muster (military), Σκορ: 0.1072, URL: https://en.wikipedia.org/wiki/Muster_(military)
# 8. ID: 862, Τίτλος: Bahawalnagar incident, Σκορ: 0.0988, URL: https://en.wikipedia.org/wiki/Bahawalnagar_incident
# 9. ID: 26, Τίτλος: Henry J. Abraham, Σκορ: 0.0908, URL: https://en.wikipedia.org/wiki/Henry_J._Abraham
# 10. ID: 745, Τίτλος: Tomasz Kucharzewski, Σκορ: 0.0861, URL: https://en.wikipedia.org/wiki/Tomasz_Kucharzewski
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): Punjabi culture
# Επιλέξτε αλγόριθμο (TF-IDF, BM25, VSM): BM25
# Βρέθηκαν 73 σχετικά έγγραφα με τον αλγόριθμο BM25:
#
# 1. ID: 4, Τίτλος: Sikh culture, Σκορ: 15.9240, URL: https://en.wikipedia.org/wiki/Sikh_culture
# 2. ID: 889, Τίτλος: Oye Bhole Oye, Σκορ: 11.0682, URL: https://en.wikipedia.org/wiki/Oye_Bhole_Oye
# 3. ID: 710, Τίτλος: Rasheed Kidwai, Σκορ: 5.7418, URL: https://en.wikipedia.org/wiki/Rasheed_Kidwai
# 4. ID: 906, Τίτλος: The New World Order (album), Σκορ: 5.4802, URL: https://en.wikipedia.org/wiki/The_New_World_Order_(album)
# 5. ID: 180, Τίτλος: Hamlet Petrosyan, Σκορ: 5.3128, URL: https://en.wikipedia.org/wiki/Hamlet_Petrosyan
# 6. ID: 69, Τίτλος: Joseba Arregui Aramburu, Σκορ: 4.8009, URL: https://en.wikipedia.org/wiki/Joseba_Arregui_Aramburu
# 7. ID: 1000, Τίτλος: Gama Singh, Σκορ: 4.4240, URL: https://en.wikipedia.org/wiki/Gama_Singh
# 8. ID: 365, Τίτλος: Paulo Costa Lima, Σκορ: 4.0072, URL: https://en.wikipedia.org/wiki/Paulo_Costa_Lima
# 9. ID: 920, Τίτλος: List of venues in Neath Port Talbot, Σκορ: 3.8702, URL: https://en.wikipedia.org/wiki/List_of_venues_in_Neath_Port_Talbot
# 10. ID: 387, Τίτλος: Edward Blondin, Σκορ: 3.8587, URL: https://en.wikipedia.org/wiki/Edward_Blondin
# Εισάγετε το ερώτημά σας (ή γράψτε 'exit' για τερματισμό): exit
# Τερματισμός αναζήτησης.

# %% [markdown]
# ### Βήμα 5. Αξιολόγηση συστήματος:

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Παράδειγμα δοκιμαστικών ερωτημάτων και αναμενόμενων απαντήσεων
test_queries = [
    {"query": "Israeli writer", "relevant_docs": [3]},
    {"query": "animal actors", "relevant_docs": [1]},
    {"query": "US Army general", "relevant_docs": [10]},
    {"query": "Punjabi culture", "relevant_docs": [4]},
]

# Συνάρτηση για αξιολόγηση
def evaluate_search_engine(algorithm="TF-IDF"):
    precisions = []
    recalls = []
    f1_scores = []
    average_precisions = []
    
    for test in test_queries:
        query = test['query']
        relevant_docs = set(test['relevant_docs'])

        # Λήψη αποτελεσμάτων με κατάταξη
        ranked_results = rank_results(query, algorithm)
        retrieved_docs = set(doc_id for doc_id, _ in ranked_results)

        # Υπολογισμός Precision, Recall, F1
        tp = len(retrieved_docs & relevant_docs)  # True Positives
        fp = len(retrieved_docs - relevant_docs)  # False Positives
        fn = len(relevant_docs - retrieved_docs)  # False Negatives

        precision = tp / (tp + fp) if tp + fp > 0 else 0
        recall = tp / (tp + fn) if tp + fn > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0

        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)

        # Υπολογισμός Average Precision (AP)
        average_precision = 0
        for k, (doc_id, _) in enumerate(ranked_results):
            if doc_id in relevant_docs:
                precision_at_k = len(relevant_docs & set([doc_id for doc_id, _ in ranked_results[:k+1]])) / (k + 1)
                average_precision += precision_at_k
        average_precision /= len(relevant_docs) if relevant_docs else 1
        average_precisions.append(average_precision)

    # Υπολογισμός μέσων τιμών
    mean_precision = sum(precisions) / len(precisions)
    mean_recall = sum(recalls) / len(recalls)
    mean_f1 = sum(f1_scores) / len(f1_scores)
    mean_ap = sum(average_precisions) / len(average_precisions)

    print(f"Αποτελέσματα για τον αλγόριθμο {algorithm}:")
    print(f"- Μέση Ακρίβεια (Precision): {mean_precision:.4f}")
    print(f"- Μέση Ανάκληση (Recall): {mean_recall:.4f}")
    print(f"- Μέσο F1-Score: {mean_f1:.4f}")
    print(f"- Μέση Ακρίβεια (MAP): {mean_ap:.4f}")

# Εκτέλεση αξιολόγησης για όλους τους αλγορίθμους
for algo in ["TF-IDF", "BM25", "VSM"]:
    evaluate_search_engine(algo)
# Out:
# Αποτελέσματα για τον αλγόριθμο TF-IDF:
# - Μέση Ακρίβεια (Precision): 0.0120
# - Μέση Ανάκληση (Recall): 1.0000
# - Μέσο F1-Score: 0.0236
# - Μέση Ακρίβεια (MAP): 0.4811
# Αποτελέσματα για τον αλγόριθμο BM25:
# - Μέση Ακρίβεια (Precision): 0.0120
# - Μέση Ανάκληση (Recall): 1.0000
# - Μέσο F1-Score: 0.0236
# - Μέση Ακρίβεια (MAP): 0.7500
# Αποτελέσματα για τον αλγόριθμο VSM:
# - Μέση Ακρίβεια (Precision): 0.0120
# - Μέση Ανάκληση (Recall): 1.0000
# - Μέσο F1-Score: 0.0236
# - Μέση Ακρίβεια (MAP): 0.4811

# %% [markdown]
# ### Βήμα 6. Αναφορά και τεκμηρίωση:

# %% [markdown]
# Εισαγωγή
# Η παρούσα εργασία επικεντρώνεται στη δημιουργία μιας μηχανής αναζήτησης με στόχο την κατανόηση των βασικών εννοιών της ανάκτησης πληροφορίας, της ευρετηρίασης, της κατάταξης και της επεξεργασίας ερωτημάτων. Η υλοποίηση περιλαμβάνει τη συλλογή δεδομένων, την προεπεξεργασία κειμένου, την κατασκευή ανεστραμμένου ευρετηρίου, την υποστήριξη Boolean αναζητήσεων και την αξιολόγηση της απόδοσης με μετρικές όπως Precision, Recall, και MAP.
# ________________________________________
# Βήμα 1: Συλλογή Δεδομένων
# Περιγραφή του Dataset
# Χρησιμοποιήθηκε το σύνολο δεδομένων articles.json, το οποίο περιέχει άρθρα από τη Wikipedia. Κάθε άρθρο περιλαμβάνει:
# •	ID: Ένα μοναδικό αναγνωριστικό.
# •	Title: Τον τίτλο του άρθρου.
# •	Body: Το κύριο περιεχόμενο.
# •	URL: Σύνδεσμο προς το πρωτότυπο άρθρο.
# Μεθοδολογία
# Τα δεδομένα φορτώθηκαν και αναλύθηκαν σε Python, διασφαλίζοντας την εγκυρότητα και πληρότητά τους. Η συλλογή περιέχει επαρκή αριθμό άρθρων για τις ανάγκες της εργασίας.
# ________________________________________
# Βήμα 2: Προεπεξεργασία Κειμένου
# Επιλογές και Ενέργειες
# Για την προετοιμασία των δεδομένων εφαρμόστηκαν:
# 1.	Tokenization: Χωρισμός του κειμένου σε λέξεις.
# 2.	Stop-word Removal: Αφαίρεση κοινών λέξεων χωρίς σημασιολογική αξία.
# 3.	Stemming: Κανονικοποίηση λέξεων για την εξάλειψη μορφολογικών διαφορών.
# 4.	Καθαρισμός Κειμένου: Αφαίρεση ειδικών χαρακτήρων και μετατροπή σε πεζά γράμματα.
# Τα δεδομένα αποθηκεύτηκαν σε νέο JSON αρχείο, εμπλουτισμένο με τα επεξεργασμένα κείμενα.
# ________________________________________
# Βήμα 3: Ευρετήριο (Indexing)
# Υλοποίηση
# Δημιουργήθηκε ένα ανεστραμμένο ευρετήριο που αντιστοιχίζει κάθε μοναδική λέξη στα άρθρα όπου εμφανίζεται. Για κάθε λέξη καταγράφεται:
# •	Το ID των εγγράφων όπου εμφανίζεται.
# •	Η συχνότητα εμφάνισης στο κάθε έγγραφο.
# Το ευρετήριο αποθηκεύτηκε σε μορφή JSON για ταχύτερη αναζήτηση.
# ________________________________________
# Βήμα 4: Μηχανή Αναζήτησης
# Επεξεργασία Ερωτήματος
# Η μηχανή αναζήτησης υποστηρίζει Boolean ερωτήματα με τις λειτουργίες:
# •	AND: Εύρεση εγγράφων που περιέχουν όλους τους όρους.
# •	OR: Εύρεση εγγράφων που περιέχουν οποιονδήποτε από τους όρους.
# •	NOT: Εξαίρεση εγγράφων που περιέχουν έναν συγκεκριμένο όρο.
# •	AND NOT: Συνδυασμός συμπερίληψης και εξαίρεσης όρων.
# Κατάταξη Αποτελεσμάτων
# Υλοποιήθηκαν τρεις μέθοδοι κατάταξης:
# 1.	TF-IDF: Βασική προσέγγιση που αξιολογεί τη σημασία των λέξεων.
# 2.	BM25: Πιθανολογικό μοντέλο ανάκτησης με βελτιωμένη απόδοση.
# 3.	VSM: Διανυσματικό μοντέλο για μέτρηση ομοιότητας εγγράφων.
# Ο χρήστης μπορεί να επιλέξει τον αλγόριθμο κατάταξης πριν την εκτέλεση της αναζήτησης.
# ________________________________________
# Βήμα 5: Αξιολόγηση Συστήματος
# Δοκιμαστικά Ερωτήματα
# Χρησιμοποιήθηκε ένα μικρό σύνολο ερωτημάτων για αξιολόγηση:
# 1.	"Israeli writer"
# 2.	"animal actors"
# 3.	"US Army general"
# 4.	"Punjabi culture"
# Μετρικές
# Υπολογίστηκαν:
# •	Precision: Χαμηλή λόγω ανάκτησης μη σχετικών εγγράφων.
# •	Recall: Υψηλή, καθώς όλα τα σχετικά έγγραφα ανακτήθηκαν.
# •	F1-Score: Μέτρια απόδοση λόγω της ανισορροπίας Precision και Recall.
# •	MAP (Mean Average Precision): Η BM25 παρουσίασε την υψηλότερη απόδοση.
# Συγκριτικά Αποτελέσματα
# Αλγόριθμος	Precision	Recall	F1-Score	MAP
# TF-IDF	    0.0120  	1.0000	0.0236  	0.4811
# BM25	    0.0120	    1.0000	0.0236	    0.7500
# VSM	        0.0120	    1.0000	0.0236   	0.4811
# ________________________________________
# Δυσκολίες και Βελτιώσεις
# Δυσκολίες
# 1.	Χαμηλή Ακρίβεια: Επιστροφή πολλών μη σχετικών εγγράφων.
# 2.	Περιορισμένα Δεδομένα: Η μικρή κλίμακα του dataset επηρέασε την ακρίβεια της αξιολόγησης.
# Προτεινόμενες Βελτιώσεις
# 1.	Ενσωμάτωση μεγαλύτερων και πιο ποικίλων datasets.
# 2.	Βελτίωση του συστήματος κατάταξης με συνδυασμό αλγορίθμων.
# ________________________________________
# Συμπεράσματα
# Η μηχανή αναζήτησης που αναπτύχθηκε παρέχει μια καλή βάση για την ανάκτηση πληροφορίας με υποστήριξη βασικών και προηγμένων αλγορίθμων. Αν και οι μετρικές δείχνουν δυνατά και αδύναμα σημεία, η υλοποίηση είναι επεκτάσιμη και μπορεί να βελτιωθεί με μελλοντικές βελτιώσεις.
